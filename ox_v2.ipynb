# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
lst = [(51.5054643, -0.0237504), (51.5056454, -0.0227653), (51.5055632, -0.0220232), (51.5053797, -0.0202910), (51.5052808, -0.0193272), (51.5050233, -0.0171228), (51.5050981, -0.0169550), (51.5049883, -0.0167906), (51.5049203, -0.0170072), (51.5044129, -0.0171497), (51.5043337, -0.0169904), (51.5041777, -0.0172207), (51.5043666, -0.0173104), (51.5045539, -0.0193989), (51.5048406, -0.0217213), (51.5049741, -0.0229823), (51.5053693, -0.0234795), (51.5053269, -0.0237804), (51.5035762, -0.0173631), (51.5032254, -0.0174689), (51.5039358, -0.0200314), (51.5033337, -0.0200694), (51.5035125, -0.0222213), (51.5038699, -0.0247795)]

lon = []
lat = []
for k, l in lst:
    lon.append(k)
    lat.append(l)

# %%
import networkx as nx
# import matplotlib to visualise the data
import matplotlib.pyplot as plt
i = 20.0
# Create a graph object
MyGraph = nx.Graph()
fig, ax = plt.subplots(1,1, figsize=(20, 15))
#MyGraph.add_node('h', npos = (-0.02090781927108765 + i, 51.50473573689897 + i), ccn = '#FFA500')
MyGraph.add_node('A', npos = (-0.017217099666595462, 51.50444189675956), ccn = '#FFA500')
MyGraph.add_node('B', npos = (-0.01706957817077637, 51.5044318794487), ccn = '#FFA500')
MyGraph.add_node('C', npos = (-0.01699447631835938, 51.50439014062966), ccn = '#FFA500')
MyGraph.add_node('D', npos = (-0.017034709453582767, 51.50429330642228), ccn = '#FFA500')
MyGraph.add_node('E', npos = (-0.017133951187133793, 51.5042315327686), ccn = '#FFA500')
MyGraph.add_node('F', npos = (-0.017300248146057132, 51.50425156747632), ccn = '#FFA500')
MyGraph.add_node('G', npos = (-0.017364621162414554, 51.50441017526758), ccn = '#FFA500')
MyGraph.add_node('H', npos = (-0.017407536506652836, 51.50433003666309), ccn = '#FFA500')
MyGraph.add_node('H', npos = (-0.01941919326782227, 51.504505339677316), ccn = '#FFA500')
MyGraph.add_node('I', npos = (-0.0194084644317627, 51.50460384297987), ccn = '#FFA500')
MyGraph.add_node('J', npos = (-0.02087831497192383, 51.504774136322645), ccn = '#FFA500')
MyGraph.add_node('K', npos = (-0.02090781927108765, 51.50470735469545), ccn = '#FFA500')
MyGraph.add_node('L', npos = (-0.022994577884674076, 51.50493107276133), ccn = '#FFA500')
MyGraph.add_node('M', npos = (-0.022975802421569828, 51.50501287983954), ccn = '#FFA500')
MyGraph.add_node('N', npos = (-0.02340495586395264, 51.50536347993971), ccn = '#FFA500')
MyGraph.add_node('O', npos = (-0.023544430732727054, 51.50537850559799), ccn = '#FFA500')
MyGraph.add_node('P', npos = (-0.023614168167114258, 51.505032914203625), ccn = '#00FF00')
MyGraph.add_node('Q', npos = (-0.02348005771636963, 51.50508466960348), ccn = '#FFA500')
MyGraph.add_node('R', npos = (-0.023603439331054688, 51.5052399354503), ccn = '#FFA500')
MyGraph.add_node('S', npos = (-0.023804605007171634, 51.50528501253254), ccn = '#FFA500')
MyGraph.add_node('T', npos = (-0.023772418498992923, 51.505396870284734), ccn = '#FFA500')
MyGraph.add_node('U', npos = (-0.023734867572784427, 51.50550872776233), ccn = '#FFA500')
MyGraph.add_node('V', npos = (-0.023533701896667484, 51.50554044848958), ccn = '#00FF00')
MyGraph.add_node('W', npos = (-0.023378133773803714, 51.505737450406535), ccn = '#00FF00')
MyGraph.add_node('X', npos = (-0.02275854349136353, 51.50568402624205), ccn = '#FFA500')
MyGraph.add_node('Y', npos = (-0.022780001163482666, 51.50560555938688), ccn = '#FFA500')
MyGraph.add_node('Z', npos = (-0.02206653356552124, 51.505522083860726), ccn = '#FFA500')
MyGraph.add_node('a', npos = (-0.022039711475372314, 51.50560555938688), ccn = '#FFA500')
MyGraph.add_node('b', npos = (-0.02108484506607056, 51.50550204971169), ccn = '#FFA500')
MyGraph.add_node('c', npos = (-0.02111703157424927, 51.5054202435117), ccn = '#FFA500')
MyGraph.add_node('d', npos = (-0.020309686660766605, 51.50533342860824), ccn = '#FFA500')
MyGraph.add_node('e', npos = (-0.020277500152587894, 51.50541356544807), ccn = '#FFA500')
MyGraph.add_node('f', npos = (-0.019365549087524418, 51.505321741973994), ccn = '#FFA500')
MyGraph.add_node('g', npos = (-0.019395053386688236, 51.50524661353936), ccn = '#FFA500')
MyGraph.add_node('h', npos = (-0.017050802707672123, 51.505134755418325), ccn = '#FFA500')
MyGraph.add_node('i', npos = (-0.016868412494659427, 51.505118060152824), ccn = '#FFA500')
MyGraph.add_node('j', npos = (-0.016804039478302005, 51.5050562876173), ccn = '#FFA500')
MyGraph.add_node('k', npos = (-0.01683890819549561, 51.50495444622724), ccn = '#FFA500')
MyGraph.add_node('l', npos = (-0.01693278551101685, 51.504904360214184), ccn = '#FFA500')
MyGraph.add_node('m', npos = (-0.017085671424865726, 51.50493107276133), ccn = '#FFA500')
MyGraph.add_node('n', npos = (-0.017158091068267826, 51.504987836872004), ccn = '#FFA500')
MyGraph.add_node('o', npos = (-0.017133951187133793, 51.50508633913154), ccn = '#FFA500')
MyGraph.add_node('p', npos = (-0.01730829477310181, 51.503570382474955), ccn = '#FFA500')
MyGraph.add_node('q', npos = (-0.017439723014831546, 51.503588747890404), ccn = '#FFA500')
MyGraph.add_node('r', npos = (-0.017415583133697513, 51.503223107771085), ccn = '#FFA500')
MyGraph.add_node('s', npos = (-0.017541646957397464, 51.5032364645394), ccn = '#FFA500')
MyGraph.add_node('t', npos = (-0.018458962440490726, 51.50376238417993), ccn = '#00FF00')
MyGraph.add_node('u', npos = (-0.018520653247833255, 51.503219768578404), ccn = '#FFA500')
MyGraph.add_node('v', npos = (-0.019738376140594486, 51.503406762992256), ccn = '#FFA500')
MyGraph.add_node('w', npos = (-0.019950270652771, 51.50338171914205), ccn = '#FFA500')
MyGraph.add_node('x', npos = (-0.020028054714202884, 51.50396273292259), ccn = '#00FF00')
MyGraph.add_node('y', npos = (-0.019775927066802982, 51.504436888104415), ccn = '#00FF00')
MyGraph.add_node('z', npos = (-0.020092427730560306, 51.50332328343802), ccn = '#FFA500')
MyGraph.add_node('1', npos = (-0.02211481332778931, 51.50360377413393), ccn = '#FFA500')
MyGraph.add_node('2', npos = (-0.02214699983596802, 51.50350693825546), ccn = '#FFA500')
MyGraph.add_node('3', npos = (-0.024917721748352054, 51.503900958820886), ccn = '#FFA500')
MyGraph.add_node('4', npos = (-0.024952590465545658, 51.50382081932085), ccn = '#FFA500')
MyGraph.add_node('#', npos = (-0.01738071441650391, 51.504316680215304), ccn = '#FFA500')
MyGraph.add_node('|', npos = (-0.01983761787414551, 51.50432001932763), ccn = '#FF0000')

MyGraph.add_edge('W', 'X', cce='#0000FF')
MyGraph.add_edge('X', 'Y', cce='#0000FF')
MyGraph.add_edge('X', 'a', cce='#0000FF')
MyGraph.add_edge('Y', 'Z', cce='#0000FF')
MyGraph.add_edge('a', 'Z', cce='#0000FF')
MyGraph.add_edge('x', '|', cce='#0000FF')
MyGraph.add_edge('|', 'y', cce='#0000FF')

MyGraph.add_edge('a', 'b', cce='#0000FF')
MyGraph.add_edge('b', 'c', cce='#0000FF')
MyGraph.add_edge('c', 'Z', cce='#0000FF')
MyGraph.add_edge('b', 'e', cce='#0000FF')
MyGraph.add_edge('e', 'd', cce='#0000FF')

MyGraph.add_edge('c', 'd', cce='#0000FF')
MyGraph.add_edge('e', 'f', cce='#0000FF')
MyGraph.add_edge('f', 'g', cce='#0000FF')
MyGraph.add_edge('d', 'g', cce='#0000FF')
MyGraph.add_edge('f', 'o', cce='#0000FF')

MyGraph.add_edge('o', 'n', cce='#0000FF')
MyGraph.add_edge('n', 'g', cce='#0000FF')
MyGraph.add_edge('o', 'h', cce='#0000FF')
MyGraph.add_edge('h', 'i', cce='#0000FF')
MyGraph.add_edge('i', 'j', cce='#0000FF')

MyGraph.add_edge('j', 'k', cce='#0000FF')
MyGraph.add_edge('k', 'l', cce='#0000FF')
MyGraph.add_edge('l', 'm', cce='#0000FF')
MyGraph.add_edge('m', 'n', cce='#0000FF')

MyGraph.add_edge('l', 'B', cce='#0000FF')
MyGraph.add_edge('m', 'A', cce='#0000FF')
MyGraph.add_edge('A', 'B', cce='#0000FF')
MyGraph.add_edge('B', 'C', cce='#0000FF')

MyGraph.add_edge('C', 'D', cce='#0000FF')
MyGraph.add_edge('D', 'E', cce='#0000FF')
MyGraph.add_edge('E', 'F', cce='#0000FF')
MyGraph.add_edge('F', 'G', cce='#0000FF')

MyGraph.add_edge('G', 'I', cce='#0000FF')
MyGraph.add_edge('F', 'H', cce='#0000FF')
MyGraph.add_edge('I', 'H', cce='#0000FF')
MyGraph.add_edge('I', 'J', cce='#0000FF')

MyGraph.add_edge('J', 'K', cce='#0000FF')
MyGraph.add_edge('K', 'H', cce='#0000FF')
MyGraph.add_edge('J', 'M', cce='#0000FF')
MyGraph.add_edge('M', 'L', cce='#0000FF')

MyGraph.add_edge('L', 'K', cce='#0000FF')
MyGraph.add_edge('M', 'Q', cce='#0000FF')
MyGraph.add_edge('Q', 'R', cce='#0000FF')
MyGraph.add_edge('R', 'N', cce='#0000FF')

MyGraph.add_edge('P', 'S', cce='#0000FF')
MyGraph.add_edge('S', 'T', cce='#0000FF')
MyGraph.add_edge('T', 'U', cce='#0000FF')
MyGraph.add_edge('T', 'O', cce='#0000FF')

MyGraph.add_edge('O', 'N', cce='#0000FF')
MyGraph.add_edge('U', 'V', cce='#0000FF')
MyGraph.add_edge('V', 'W', cce='#0000FF')
MyGraph.add_edge('H', 'y', cce='#0000FF')

MyGraph.add_edge('y', 'x', cce='#0000FF')
MyGraph.add_edge('E', 'p', cce='#0000FF')
MyGraph.add_edge('F', 'q', cce='#0000FF')
MyGraph.add_edge('p', 'q', cce='#0000FF')

MyGraph.add_edge('q', 't', cce='#0000FF')
MyGraph.add_edge('t', 'x', cce='#0000FF')
MyGraph.add_edge('p', 'r', cce='#0000FF')
MyGraph.add_edge('q', 's', cce='#0000FF')

MyGraph.add_edge('r', 's', cce='#0000FF')
MyGraph.add_edge('s', 'u', cce='#0000FF')
MyGraph.add_edge('u', 't', cce='#0000FF')
MyGraph.add_edge('u', 'v', cce='#0000FF')

MyGraph.add_edge('v', 'w', cce='#0000FF')
MyGraph.add_edge('w', 'z', cce='#0000FF')
MyGraph.add_edge('x', 'w', cce='#0000FF')
MyGraph.add_edge('w', '1', cce='#0000FF', style = '--')

MyGraph.add_edge('z', '2', cce='#0000FF')
MyGraph.add_edge('1', '2', cce='#0000FF')
MyGraph.add_edge('3', '4', cce='#0000FF')
MyGraph.add_edge('1', '3', cce='#0000FF')
MyGraph.add_edge('2', '4', cce='#0000FF')
MyGraph.add_edge('L', 'P', cce='#0000FF')
MyGraph.add_edge('A', 'G', cce='#0000FF')
MyGraph.add_edge('F', '#', cce='#0000FF')
MyGraph.add_edge('#', 'G', cce='#0000FF')
MyGraph.add_edge('H', '#', cce='#0000FF')


MyGraph.remove_edge('H', 'F')
MyGraph.remove_edge('F', 'G')
MyGraph.remove_edge('x', 'y')

pos = nx.get_node_attributes(MyGraph, 'npos')
nodecolour = nx.get_node_attributes(MyGraph, 'ccn')
edgecolour = nx.get_edge_attributes(MyGraph, 'cce')

NodeList = list(nodecolour.values())
EdgeList = list(edgecolour.values())

nx.draw_networkx(MyGraph, pos, node_color=NodeList, node_size = 250)
nx.draw_networkx_edges(MyGraph, pos, edge_color=EdgeList, width = 4, alpha = 0.5, style = '--')




#plt.text(-0.022354978179932, 51.50410052303076, s = 'CANARY WHARF', size = 25)
#plt.xticks()
plt.ylim(min(lon) - 0.0002, max(lon) + 0.0002)
plt.xlim(min(lat) - 0.0002, max(lat) + 0.0002)
plt.title("Canary Wharf Travelling Routes: London", size = 25)
plt.xlabel("Latitude", size = 20)
plt.ylabel("Longitude", size = 20)
#plt.xticks(lat, lat)
#plt.yticks(lon)
#image = mpimg.imread(r'E:\MSc Project\final_map.png')
#plt.imshow(image)
#plt.tight_layout()
plt.show()
#pos

# %%
longitude = []
latitude = []

for i in pos.values():
    longitude.append(i[0])
    latitude.append(i[1])

# %%
points = pos['A'], pos['B'], pos['C'], pos['D'], pos['E'], pos['F'], pos['#'], pos['G'], pos['A'], pos['G'], pos['I'], pos['H'], pos['#'], pos['H'], pos['K'], pos['J'], pos['I'], pos['J'], pos['M'], pos['L'], pos['K'], pos['L'], pos['P'], pos['S'], pos['T'], pos['O'], pos['N'], pos['R'], pos['Q'], pos['M'], pos['Q'], pos['R'], pos['N'], pos['O'], pos['T'], pos['U'], pos['V'], pos['W'], pos['X'], pos['Y'], pos['Z'], pos['a'], pos['X'], pos['a'], pos['b'], pos['c'], pos['Z'], pos['c'], pos['d'], pos['e'], pos['b'], pos['e'], pos['f'], pos['g'], pos['d'], pos['g'], pos['n'], pos['o'], pos['f'], pos['o'], pos['h'], pos['i'], pos['j'], pos['k'], pos['l'], pos['m'], pos['n'], pos['m'], pos['A'], pos['B'], pos['l'], pos['B'], pos['C'], pos['D'], pos['E'], pos['p'], pos['r'], pos['s'], pos['q'], pos['p'], pos['q'], pos['F'], pos['q'], pos['t'], pos['u'], pos['s'], pos['u'], pos['t'], pos['x'], pos['y'], pos['H'], pos['y'], pos['x'], pos['t'], pos['u'], pos['v'], pos['w'], pos['x'], pos['w'], pos['z'], pos['2'], pos['1'], pos['w'], pos['1'], pos['3'], pos['4'], pos['2']

# %%
import panel as pn
import folium
from folium import plugins
from folium.utilities import normalize

from jinja2 import Template
import matplotlib.pyplot as plt
import folium

import ipywidgets as widgets
import matplotlib.pyplot as plt
import folium
Latitude = 51.5045
Longitude = -0.0204
UMMlocation = (Latitude, Longitude)
map_UMM = folium.Map(location = UMMlocation, width = "100%", zoom_start = 18, prefer_canvas = True, tiles = 'openstreetmap', opacity = 100) # max zoom: 18
map_UMM

pavements = []
for i in points:
    pavements.append((i[1], i[0]))

op1 = []
for i in pos.keys():
    op1.append(i)

source = widgets.Dropdown(
    options=op1,
    value='W',
    description='Source:',
    disabled=False,
)

destinition = widgets.Dropdown(
    options=op1,
    value='x',
    description='destinition:',
    disabled=False,
)


def generate_Map(source, destinition):
    Latitude = 51.5045
    Longitude = -0.0204
    UMMlocation = (Latitude, Longitude)
    map_UMM = folium.Map(location = UMMlocation, width = "100%", zoom_start = 17.8, prefer_canvas = True, tiles = 'cartodbpositron', opacity = 100) # max zoom: 18
    map_UMM

    for lat, lng in zip(latitude, longitude):

        #label = '{}'.format(County)
        #label = folium.Popup(label, parse_html=True)
        folium.CircleMarker(
        [lat, lng],
        radius=2,
        #popup=label,
        color='blue',
        fill=True,
        fill_color='#FFFFFF',
        fill_opacity=1.0,
        parse_html=False).add_to(map_UMM)
        #folium.PolyLine((lat, lng), color="red", weight=2.5, opacity=1).add_to(map_UMM)
    folium.PolyLine(pavements, color="red", weight=2.5, opacity=0.2).add_to(map_UMM)


    #cities = op1
    #options = pn.widgets.Select(name='Source', options=cities, width=200)
    #source = input('Please enter the source: ')
    #destination = input('Please enter the destination: ')
    path = nx.dijkstra_path(MyGraph, source, destinition)

    locations = []


    for i in path:
        locations.append([pos[i][1], pos[i][0]])

    antpath = plugins.AntPath(locations=locations, color = 'blue', weight = 1.5, opacity = 1.0)
    antpath.add_to(map_UMM)
    display(map_UMM)
    plt.show()
    
widgets.interact(generate_Map, source = source, destinition = destinition)
# Out:
# interactive(children=(Dropdown(description='Source:', index=22, options=('A', 'B', 'C', 'D', 'E', 'F', 'G', 'H…
# <function __main__.generate_Map(source, destinition)>
